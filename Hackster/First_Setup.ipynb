# %% [markdown]
# ### 1. WiFi Connection.
#
# First we connect the board to the WiFi network.

# %%
from pynq.lib import Wifi

port = Wifi()
ssid = "YOUR SSID"
pwd = "YOUR PASSWORD"
port.connect(ssid, pwd)
print("WiFi Ready")

# %% [markdown]
# ### 2. Installation of the necessary packages for the project.
#
# The notebook allows us to access terminal commands by using the "!" before the command that you want to execute in the console.

# %%
# !sudo apt-get update && sudo apt-get install -y build-essential python3-pip python3-dev python3-setuptools python3-numpy python3-scipy libatlas3-base python3-sklearn python3-paho-mqtt mosquitto mosquitto-clients && pip3 install cloudant pushetta ibmiotf
print("All the Packages was installed correctly")
# Out:
# Hit:1 http://ports.ubuntu.com/ubuntu-ports bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# python3-dev is already the newest version (3.6.5-3).
# python3-setuptools is already the newest version (39.0.1-2).
# python3-pip is already the newest version (9.0.1-2).
# The following additional packages will be installed:
#   libev4 libmosquitto1 libwebsockets8 python-attr python-funcsigs
#   python-pluggy python-py python-pytest python-six python3-joblib python3-nose
#   python3-simplejson python3-sklearn-lib
# Suggested packages:
#   apparmor python-attr-doc python-funcsigs-doc subversion python-pytest-xdist
#   python-mock python-nose-doc python-numpy-doc python3-numpy-dbg
#   python-scipy-doc python3-dap python-sklearn-doc ipython3
# The following NEW packages will be installed:
# ...

# %% [markdown]
# ### 3. Check the IP of the board.
#
# It is a data that we will use later so write it :D

# %%
# !hostname -I
